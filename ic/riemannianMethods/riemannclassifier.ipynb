# %% [markdown]
# # Exploration of Classic Riemannian Methods
# In this notebook, we will explore Riemannian classification techiniques on covariance matrices.<br>
# We will try k-NN, R-MDM and SVM on the data, using covariance estimators such as LWF.<br>
# Also, we will explore preprocessing such as xDAWN.

# %%
#Lib
import sys
sys.path.append("/home/rffl/files/eegconv/k-class")

import pyriemann as rmn
import numpy as np
import sklearn
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import kclass_lsubgen
import matplotlib.pyplot as plt

# %%
# Parameters
classvec = [i+1 for i in range(5)]
subvec = [i+1 for i in range(10)]
prop = 0.75
metric = "riemann"
estimator = "lwf"
xDAWN_filters = 5

# %% [markdown]
# ## Data processing

# %% [markdown]
# ### Data generation

# %%
train_path, test_path = kclass_lsubgen.generatedataset(classvec, subvec, prop, False)

# Data vectors
X_train = np.load(train_path, allow_pickle=True) # signals
X_test  = np.load(test_path, allow_pickle=True)
y_train = np.array([])           # labels
part = len(X_train) // len(classvec)
for i in range(len(classvec)):
    y_train = np.concatenate([y_train, i * np.ones(part, dtype=np.int64)])

y_test = np.array([])
part = len(X_test) // len(classvec)
for i in range(len(classvec)):
    y_test = np.concatenate([y_test, i * np.ones(part, dtype=np.int64)])
# Out:
# Saved ./kclass-lsubtrain.npy shape = (3000, 17, 100)
# Saved ./kclass-lsubtest.npy shape = (1000, 17, 100)

# %% [markdown]
# ### Data processing - Regular Covariance

# %%
cov = rmn.estimation.Covariances(estimator=estimator)
X_train_cov = cov.fit_transform(X_train)
X_test_cov = cov.transform(X_test)

# %% [markdown]
# ### Data Processing - XDawn

# %%
cov = rmn.estimation.XdawnCovariances(nfilter=xDAWN_filters, estimator=estimator)
X_train_cov = cov.fit_transform(X_train, y_train)
X_test_cov = cov.transform(X_test)

# %% [markdown]
# ## Algorithms

# %% [markdown]
# ### MDM

# %%
classifier = rmn.classification.MDM(metric=metric)
classifier.fit(X_train_cov, y_train)
y_pred = classifier.predict(X_test_cov)

corr = 0
for i in range(len(y_pred)):
    if y_pred[i] == y_test[i]:
        corr += 1

print("Acc " + str(corr/len(y_pred)))
cm = confusion_matrix(y_test, y_pred, labels=classifier.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classifier.classes_)
disp.plot()
plt.show()
# Out:
# Acc 0.323

# %% [markdown]
# ### K-NN

# %%
classifier = rmn.classification.KNearestNeighbor(3, metric)
classifier.fit(X_train_cov, y_train)
y_pred = classifier.predict(X_test_cov)

corr = 0
for i in range(len(y_pred)):
    if y_pred[i] == y_test[i]:
        corr += 1

print("Acc " + str(corr/len(y_pred)))
cm = confusion_matrix(y_test, y_pred, labels=classifier.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classifier.classes_)
disp.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 classifier = rmn.classification.KNearestNeighbor(3, metric)
#       2 classifier.fit(X_train_cov, y_train)
# ----> 3 y_pred = classifier.predict(X_test_cov)
#       5 corr = 0
#       6 for i in range(len(y_pred)):
#
# File ~/miniconda3/envs/eeg/lib/python3.11/site-packages/pyriemann/classification.py:551, in KNearestNeighbor.predict(self, X, covtest)
#     548     assert (X is None)
#     549     X = covtest
# --> 551 dist = self._predict_distances(X)
#     552 neighbors_classes = self.classmeans_[np.argsort(dist)]
#     553 pred = _mode_2d(neighbors_classes[:, 0:self.n_neighbors], axis=1)
#
# File ~/miniconda3/envs/eeg/lib/python3.11/site-packages/pyriemann/classification.py:143, in MDM._predict_distances(self, X)
#     140 """Helper to predict the distance. Equivalent to transform."""
#     142 if self.n_jobs == 1:
# --> 143     dist = [
#     144         distance(X, covmean, self.metric_dist)
#     145         for covmean in self.covmeans_
#     146     ]
#     147 else:
#     148     dist = Parallel(n_jobs=self.n_jobs)(
#     149         delayed(distance)(
#     150             X, covmean, self.metric_dist
#     151         ) for covmean in self.covmeans_
#     152     )
#
# File ~/miniconda3/envs/eeg/lib/python3.11/site-packages/pyriemann/classification.py:144, in <listcomp>(.0)
#     140 """Helper to predict the distance. Equivalent to transform."""
#     142 if self.n_jobs == 1:
#     143     dist = [
# --> 144         distance(X, covmean, self.metric_dist)
#     145         for covmean in self.covmeans_
#     146     ]
#     147 else:
#     148     dist = Parallel(n_jobs=self.n_jobs)(
#     149         delayed(distance)(
#     150             X, covmean, self.metric_dist
#     151         ) for covmean in self.covmeans_
#     152     )
#
# File ~/miniconda3/envs/eeg/lib/python3.11/site-packages/pyriemann/utils/distance.py:600, in distance(A, B, metric, squared)
#     598     d = np.empty((shape_A[0], 1))
#     599     for i in range(shape_A[0]):
# --> 600         d[i] = distance_function(A[i], B, squared=squared)
#     601 else:
#     602     raise ValueError("Inputs have incompatible dimensions.")
#
# File ~/miniconda3/envs/eeg/lib/python3.11/site-packages/pyriemann/utils/distance.py:489, in distance_riemann(A, B, squared)
#     449 r"""Affine-invariant Riemannian distance between SPD/HPD matrices.
#     450
#     451 The affine-invariant Riemannian distance between two SPD/HPD matrices
#    (...)    486     M. Moakher. SIAM J Matrix Anal Appl, 2005, 26 (3), pp. 735-747
#     487 """
#     488 _check_inputs(A, B)
# --> 489 d2 = (np.log(_recursive(eigvalsh, A, B))**2).sum(axis=-1)
#     490 return d2 if squared else np.sqrt(d2)
#
# File ~/miniconda3/envs/eeg/lib/python3.11/site-packages/pyriemann/utils/distance.py:23, in _recursive(fun, A, B, *args, **kwargs)
#      21 """Recursive function with two inputs."""
#      22 if A.ndim == 2:
# ---> 23     return fun(A, B, *args, **kwargs)
#      24 else:
#      25     return np.asarray(
#      26         [_recursive(fun, a, b, *args, **kwargs) for a, b in zip(A, B)]
#      27     )
#
# File ~/miniconda3/envs/eeg/lib/python3.11/site-packages/scipy/_lib/_util.py:1233, in _apply_over_batch.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#    1231 # Early exit if call is not batched
#    1232 if not any(batch_shapes):
# -> 1233     return f(*arrays, *other_args, **kwargs)
#    1235 # Determine broadcasted batch shape
#    1236 batch_shape = np.broadcast_shapes(*batch_shapes)  # Gives OK error message
#
# File ~/miniconda3/envs/eeg/lib/python3.11/site-packages/scipy/linalg/_decomp.py:1030, in eigvalsh(a, b, lower, overwrite_a, overwrite_b, type, check_finite, subset_by_index, subset_by_value, driver)
#     917 @_apply_over_batch(('a', 2), ('b', 2))
#     918 def eigvalsh(a, b=None, *, lower=True, overwrite_a=False,
#     919              overwrite_b=False, type=1, check_finite=True, subset_by_index=None,
#     920              subset_by_value=None, driver=None):
#     921     """
#     922     Solves a standard or generalized eigenvalue problem for a complex
#     923     Hermitian or real symmetric matrix.
#    (...)   1028
#    1029     """
# -> 1030     return eigh(a, b=b, lower=lower, eigvals_only=True, overwrite_a=overwrite_a,
#    1031                 overwrite_b=overwrite_b, type=type, check_finite=check_finite,
#    1032                 subset_by_index=subset_by_index, subset_by_value=subset_by_value,
#    1033                 driver=driver)
#
# File ~/miniconda3/envs/eeg/lib/python3.11/site-packages/scipy/_lib/_util.py:1233, in _apply_over_batch.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#    1231 # Early exit if call is not batched
#    1232 if not any(batch_shapes):
# -> 1233     return f(*arrays, *other_args, **kwargs)
#    1235 # Determine broadcasted batch shape
#    1236 batch_shape = np.broadcast_shapes(*batch_shapes)  # Gives OK error message
#
# File ~/miniconda3/envs/eeg/lib/python3.11/site-packages/scipy/linalg/_decomp.py:577, in eigh(a, b, lower, eigvals_only, overwrite_a, overwrite_b, type, check_finite, subset_by_index, subset_by_value, driver)
#     573         lwork_args = {'lwork': lw}
#     575     drv_args.update({'uplo': uplo, 'jobz': _job})
# --> 577     w, v, *other_args, info = drv(a=a1, b=b1, **drv_args, **lwork_args)
#     579 # m is always the first extra argument
#     580 w = w[:other_args[0]] if subset else w
#
# KeyboardInterrupt:

# %% [markdown]
# ### SVM

# %%
# OvO
classifier = sklearn.svm.SVC(kernel="linear")
X_tang_train = rmn.tangentspace.TangentSpace(metric=metric).fit_transform(X_train_cov)
X_tang_test = rmn.tangentspace.TangentSpace(metric=metric).fit_transform(X_test_cov)
classifier.fit(X_tang_train, y_train)
y_pred = classifier.predict(X_tang_test)

corr = 0
for i in range(len(y_pred)):
    if y_pred[i] == y_test[i]:
        corr += 1

print("Acc " + str(corr/len(y_pred)))
cm = confusion_matrix(y_test, y_pred, labels=classifier.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classifier.classes_)
disp.plot()
plt.show()
# Out:
# Acc 0.553

# %%
# OvA
classifier = sklearn.svm.LinearSVC()
X_tang_train = rmn.tangentspace.TangentSpace(metric=metric).fit_transform(X_train_cov)
X_tang_test = rmn.tangentspace.TangentSpace(metric=metric).fit_transform(X_test_cov)
classifier.fit(X_tang_train, y_train)
y_pred = classifier.predict(X_tang_test)

corr = 0
for i in range(len(y_pred)):
    if y_pred[i] == y_test[i]:
        corr += 1

print("Acc " + str(corr/len(y_pred)))

cm = confusion_matrix(y_test, y_pred, labels=classifier.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classifier.classes_)
disp.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 3
#       1 # OvA
#       2 classifier = sklearn.svm.LinearSVC()
# ----> 3 X_tang_train = rmn.tangentspace.TangentSpace(metric=metric).fit_transform(X_train_cov)
#       4 X_tang_test = rmn.tangentspace.TangentSpace(metric=metric).fit_transform(X_test_cov)
#       5 classifier.fit(X_tang_train, y_train)
#
# File ~/miniconda3/envs/eeg/lib/python3.11/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~/miniconda3/envs/eeg/lib/python3.11/site-packages/pyriemann/tangentspace.py:183, in TangentSpace.fit_transform(self, X, y, sample_weight)
#     163 """Fit and transform in a single function.
#     164
#     165 Parameters
#    (...)    177     Tangent space projections of SPD matrices.
#     178 """
#     179 self.metric_mean, self.metric_map = check_metric(
#     180     self.metric, ["mean", "map"]
#     181 )
# --> 183 self.reference_ = mean_covariance(
#     184     X,
#     185     metric=self.metric_mean,
#     186     sample_weight=sample_weight
#     187 )
#     188 return tangent_space(X, self.reference_, metric=self.metric_map)
#
# File ~/miniconda3/envs/eeg/lib/python3.11/site-packages/pyriemann/utils/mean.py:785, in mean_covariance(X, metric, sample_weight, covmats, **kwargs)
#     783 X = _deprecate_covmats(covmats, X)
#     784 mean_function = check_function(metric, mean_functions)
# --> 785 M = mean_function(
#     786     X,
#     787     sample_weight=sample_weight,
#     788     **kwargs,
#     789 )
#     790 return M
#
# File ~/miniconda3/envs/eeg/lib/python3.11/site-packages/pyriemann/utils/mean.py:646, in mean_riemann(X, tol, maxiter, init, sample_weight, covmats)
#     644 for _ in range(maxiter):
#     645     M12, Mm12 = sqrtm(M), invsqrtm(M)
# --> 646     J = np.einsum("a,abc->bc", sample_weight, logm(Mm12 @ X @ Mm12))
#     647     M = M12 @ expm(nu * J) @ M12
#     649     crit = np.linalg.norm(J, ord="fro")
#
# File ~/miniconda3/envs/eeg/lib/python3.11/site-packages/pyriemann/utils/base.py:99, in logm(C)
#      77 def logm(C):
#      78     r"""Logarithm of SPD/HPD matrices.
#      79
#      80     The symmetric matrix logarithm of a SPD/HPD matrix
#    (...)     97         Matrix logarithm of C.
#      98     """
# ---> 99     return _matrix_operator(C, np.log)
#
# File ~/miniconda3/envs/eeg/lib/python3.11/site-packages/pyriemann/utils/base.py:17, in _matrix_operator(C, operator)
#      12 if C.dtype.char in typecodes['AllFloat'] and (
#      13         np.isinf(C).any() or np.isnan(C).any()):
#      14     raise ValueError(
#      15         "Matrices must be positive definite. Add "
#      16         "regularization to avoid this error.")
# ---> 17 eigvals, eigvecs = np.linalg.eigh(C)
#      18 eigvals = operator(eigvals)
#      19 if C.ndim >= 3:
#
# File ~/miniconda3/envs/eeg/lib/python3.11/site-packages/numpy/linalg/linalg.py:1487, in eigh(a, UPLO)
#    1484     gufunc = _umath_linalg.eigh_up
#    1486 signature = 'D->dD' if isComplexType(t) else 'd->dd'
# -> 1487 w, vt = gufunc(a, signature=signature, extobj=extobj)
#    1488 w = w.astype(_realType(result_t), copy=False)
#    1489 vt = vt.astype(result_t, copy=False)
#
# KeyboardInterrupt:
